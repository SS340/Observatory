# %%
from newsstream2 import headlines, summary
import textcleaner as tc 
from itertools import islice
from collections import Counter
import collections
import networkx.algorithms as xa
import networkx as nx
import collections
import context as ct

c_headlines = tc.cleantexts(headlines)
cooc = ct.return_cooc(c_headlines)
bnprobs = ct.bn_probs(cooc,ct.vocabulary(cooc),cooc)
vocab = ct.vocabulary(cooc)
bn_graph = ct.genBNgraph(bnprobs,vocab)
# vizBN(bn_graph)

# %%
from collections import Counter
def detect_N(n,graph):
    def take(n, iterable):
        return list(islice(iterable, n))
    cent = sorted(xa.in_degree_centrality(graph).items(), key=lambda kv: kv[1])[::-1]
    centrality = collections.OrderedDict(cent)
    entities = take(20,centrality.items())
    return dict(entities) 
entities = detect_N(20,bn_graph)
def list_diff(list1, list2):
    list1_ = [k[1] for k in list1]
    list2_ = [k[1] for k in list2]
    return len((Counter(list1_) - Counter(list2_)).values())
G = []
for e1 in list(entities.keys()):
    g = []
    for e2 in list(entities.keys()):
        if e2 == e1:
            pass
        elif list_diff(list(bn_graph.edges(e1)),list(bn_graph.edges(e2))) <= 1:
            g.append(e2)
    G.append((e1,g))
res = dict(G)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-140bf6e0c9de> in <module>
#       7     entities = take(20,centrality.items())
#       8     return dict(entities)
# ----> 9 entities = detect_N(20,bn_graph)
#      10 def list_diff(list1, list2):
#      11     list1_ = [k[1] for k in list1]
#
# <ipython-input-6-140bf6e0c9de> in detect_N(n, graph)
#       5     cent = sorted(xa.in_degree_centrality(graph).items(), key=lambda kv: kv[1])[::-1]
#       6     centrality = collections.OrderedDict(cent)
# ----> 7     entities = take(20,centrality.items())
#       8     return dict(entities)
#       9 entities = detect_N(20,bn_graph)
#
# <ipython-input-6-140bf6e0c9de> in take(n, iterable)
#       2 def detect_N(n,graph):
#       3     def take(n, iterable):
# ----> 4         return list(islice(iterable, n))
#       5     cent = sorted(xa.in_degree_centrality(graph).items(), key=lambda kv: kv[1])[::-1]
#       6     centrality = collections.OrderedDict(cent)
#
# NameError: name 'islice' is not defined

# %%
deleted = []
for e in list(res.keys()):
    if res[e] == []:
        pass
    else:
        for i in res[e]:
            try:
                if entities[e] > entities[i]:
                    entities.pop(i)
                    deleted.append(i)
            except KeyError:
                    pass
            try:
                if entities[e] < entities[i]:
                    entities.pop(e)
            except KeyError:
                    pass
            try:
                if entities[e] == entities[i]:
                    entities.pop(i)
            except KeyError:
                    pass    

entities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-be478af4f171> in <module>
#       1
#       2 deleted = []
# ----> 3 for e in list(res.keys()):
#       4     if res[e] == []:
#       5         pass
#
# NameError: name 'res' is not defined

# %%
cent = sorted(xa.in_degree_centrality(bn_graph).items(), key=lambda kv: kv[1])[::-1]
centrality = collections.OrderedDict(cent)

def take(n, iterable):
    return list(islice(iterable, n))

events = []
for i in entities.keys():
    n = [k[1] for k in list(bn_graph.edges(i))]
    vals = []
    for f in n:
        vals.append((f,centrality[f]))
    events.append([i]+take(10,dict(vals)))
